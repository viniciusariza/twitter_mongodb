# %%
#Documentação: https://github.com/ckoepp/TwitterSearch/

from TwitterSearch import *
from pymongo import MongoClient
from datetime import datetime, date, timedelta
import json

# %%
class API:

    def __init__(self, consumer_key, consumer_secret, access_token, access_token_secret, palavra, mongo_string, banco, collection, list_dados):
            self.consumer_key = consumer_key
            self.consumer_secret = consumer_secret
            self.access_token = access_token
            self.access_token_secret = access_token_secret
            self.palavra = palavra
            self.mongo_string = mongo_string
            self.banco = banco
            self.collection = collection
            self.list_dados = list_dados

    #Consumir API 
    def consumir_api(self, consumer_key, consumer_secret, access_token, access_token_secret, palavra):
        try:     
            ts = TwitterSearch(
            consumer_key = self.consumer_key,
            consumer_secret = self.consumer_secret,
            access_token = self.access_token,
            access_token_secret = self.access_token_secret
            )
            tso = TwitterSearchOrder()
            tso.set_keywords([self.palavra])
            tso.set_language('pt')
            tso.set_include_entities (False)

            since = datetime.now().date() - timedelta(days=1)
            until = datetime.now().date()
            tso.set_since(since)
            tso.set_until(until)
            
            self.response = ts.search_tweets_iterable(tso) 
            return self.response 

        except TwitterSearchException as e:
            return e

    #Gravar no MongoDB
    def gravar_mongo(self, mongo_string, banco, collection, list_dados):
        self.client = MongoClient(mongo_string)
        self.collection = self.client.banco.collection

        for list in list_dados:
            created_at = tweet['created_at']
            texto = tweet['text']

            data = {"date": created_at,
                    "tweet": texto
                    }
            collection.insert_one(data)

    #Converter data
    def converter_data_request(self, data):
        data_converted = datetime.strptime(data, '%a %b %d %H:%M:%S %z %Y').date()
        data_formated = created_at_converted.strftime('%Y-%m-%d')
        return data

# %%
consumer_key = "NdH4X..."
consumer_secret = "US3QH..."
access_token = "148316..."
access_token_secret = "mIT8f3JcN8HH..."
mongo_string = "mongodb://mongo:mongo@cluster0-shard-00..."

# %%
#Script landing

api = API()
busca = 'teste'
response = api.consumir_api(consumer_key, consumer_secret, access_token, access_token_secret, busca)
api.gravar_mongo(mongo_string, )

# %%
#Código sem funções

try:
    client = MongoClient(mongo_string)
    landing = client.biogas.landing

    ts = TwitterSearch(
    consumer_key = consumer_key,
    consumer_secret = consumer_secret,
    access_token = access_token,
    access_token_secret = access_token_secret
    )
    tso = TwitterSearchOrder()
    tso.set_keywords(['biogas'])
    tso.set_language('pt')
    tso.set_include_entities (False)

    since = datetime.now().date() - timedelta(days=1)
    until = datetime.now().date()
    tso.set_since(since)
    tso.set_until(until)
        
    for tweet in ts.search_tweets_iterable(tso):
        
        created_at = tweet['created_at']
        texto = tweet['text']
        created_at_converted = datetime.strptime(tweet['created_at'], '%a %b %d %H:%M:%S %z %Y').date()
        created_at_formated = created_at_converted.strftime('%Y-%m-%d')
        data = {"date": created_at_formated,
                    "tweet": texto
                }
        landing.insert_one(data)

except TwitterSearchException as e:
    print(e)
